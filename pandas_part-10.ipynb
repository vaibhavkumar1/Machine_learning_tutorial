# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df=pd.read_csv('E:\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv',na_values={"Year":"2019"})

# %%
df
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0         NaN                     Level 1                99999
# 1         NaN                     Level 1                99999
# 2         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 4         NaN                     Level 1                99999
# ...       ...                         ...                  ...
# 32440  2013.0                     Level 3                 ZZ11
# 32441  2013.0                     Level 3                 ZZ11
# 32442  2013.0                     Level 3                 ZZ11
# 32443  2013.0                     Level 3                 ZZ11
# 32444  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.dropna()
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4635   2018.0                     Level 1                99999
# 4636   2018.0                     Level 1                99999
# 4637   2018.0                     Level 1                99999
# 4638   2018.0                     Level 1                99999
# 4639   2018.0                     Level 1                99999
# ...       ...                         ...                  ...
# 32440  2013.0                     Level 3                 ZZ11
# 32441  2013.0                     Level 3                 ZZ11
# 32442  2013.0                     Level 3                 ZZ11
# 32443  2013.0                     Level 3                 ZZ11
# 32444  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 4635               All industries  Dollars (millions)           H01
# 4636               All industries  Dollars (millions)           H04
# ...

# %%
df.dropna(axis=1)
# Out:
#       Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0                         Level 1                99999
# 1                         Level 1                99999
# 2                         Level 1                99999
# 3                         Level 1                99999
# 4                         Level 1                99999
# ...                           ...                  ...
# 32440                     Level 3                 ZZ11
# 32441                     Level 3                 ZZ11
# 32442                     Level 3                 ZZ11
# 32443                     Level 3                 ZZ11
# 32444                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# ...

# %%
df.dropna(axis=0)
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4635   2018.0                     Level 1                99999
# 4636   2018.0                     Level 1                99999
# 4637   2018.0                     Level 1                99999
# 4638   2018.0                     Level 1                99999
# 4639   2018.0                     Level 1                99999
# ...       ...                         ...                  ...
# 32440  2013.0                     Level 3                 ZZ11
# 32441  2013.0                     Level 3                 ZZ11
# 32442  2013.0                     Level 3                 ZZ11
# 32443  2013.0                     Level 3                 ZZ11
# 32444  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 4635               All industries  Dollars (millions)           H01
# 4636               All industries  Dollars (millions)           H04
# ...

# %%
df.fillna("vaibhav")
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      vaibhav                     Level 1                99999
# 1      vaibhav                     Level 1                99999
# 2      vaibhav                     Level 1                99999
# 3      vaibhav                     Level 1                99999
# 4      vaibhav                     Level 1                99999
# ...        ...                         ...                  ...
# 32440     2013                     Level 3                 ZZ11
# 32441     2013                     Level 3                 ZZ11
# 32442     2013                     Level 3                 ZZ11
# 32443     2013                     Level 3                 ZZ11
# 32444     2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# ...

# %%
df.fillna(method='ffill')
# Out:
#          Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0         NaN                     Level 1                99999
# 1         NaN                     Level 1                99999
# 2         NaN                     Level 1                99999
# 3         NaN                     Level 1                99999
# 4         NaN                     Level 1                99999
# ...       ...                         ...                  ...
# 32440  2013.0                     Level 3                 ZZ11
# 32441  2013.0                     Level 3                 ZZ11
# 32442  2013.0                     Level 3                 ZZ11
# 32443  2013.0                     Level 3                 ZZ11
# 32444  2013.0                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...
