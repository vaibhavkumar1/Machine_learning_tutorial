# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
signal_img=img[:,:,1]
plt.figure(figsize=(10,9))
plt.axis("off")
img=mpimg.imread("E:\\walpaper\\pexels-photo-507410.jpeg")
plt.imshow(signal_img,cmap="Purples_r")
#plt.savefig('walpaper.png')
plt.colorbar()
plt.show()
