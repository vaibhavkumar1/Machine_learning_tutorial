# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
df=sns.load_dataset("tips")
df[['size']]
# Out:
#      size
# 0       2
# 1       3
# 2       3
# 3       2
# 4       4
# ..    ...
# 239     3
# 240     2
# 241     2
# 242     2
# 243     2
#
# [244 rows x 1 columns]

# %%
sns.distplot(df['size'])
plt.show()

# %%
sns.distplot(df['tip'])
plt.show()

# %%
sns.distplot(df['total_bill'])
plt.show()

# %%
'''sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)'''
# Out:
# 'sns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)'

# %%
sns.distplot(df['total_bill'],bins=20)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=100)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,hist=False)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,kde=False)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,rug=True)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,fit=norm)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,color='r')
plt.show()

# %%
sns.distplot(df['total_bill'],bins=10,vertical=True)
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,axlabel='Total Bill')
plt.show()

# %%
sns.distplot(df['total_bill'],bins=20,label="Total Bill")
plt.title("Histogram of total bill")
plt.legend(loc=1)
plt.show()
